# %% [markdown]
# # 🏥 Hospital Management System

# %% [markdown]
# ## 📌 Overview
#
# This project simulates a simple **Hospital Management System** using Python and Object-Oriented Programming (OOP). It allows users to manage patients, doctors, and appointments through either a command-line interface or a web interface built with **Streamlit**.
#
# This project helps students connect Python OOP concepts with a real-world use case.
#
# ---
#
# ## 🎯 Learning Objectives
#
# - Understand and implement core **OOP concepts** (classes, inheritance, composition)
# - Organize and structure Python code using modular design
# - Practice handling **user input** and basic data validation
# - Work with **CSV files** to export data
# - Build an interactive **web app** using Streamlit
#
# ---
#
# ## 🧱 Features
#
# - ✅ Add Patient (ID, Name, Age, Gender, Disease)
# - ✅ Add Doctor (ID, Name, Age, Gender, Specialty)
# - ✅ Create Appointment (link patient with doctor and date)
# - ✅ View all records (patients, doctors, appointments)
# - ✅ Export each dataset to CSV
# - ✅ Streamlit interface with dropdown menus and success messages
#
# ---
#
# ## 💻 Technologies Used
#
# - Python Object-Oriented Programming (OOP)
# - CSV File Handling
# - Streamlit
#
#
# ---

# %%
class HospitalManagementSystem:
    # Attrs: Name

    # Methods:
        # Add patient
        # Add doctor
        # Schedule appointment
        pass

class Person:
    # Attrs: ID, Name, Age, Gender
    # Methods:
        # Get details
        # Update details
        pass

class Patient(Person):
    # Attrs: Person Attrs + Disease
    # Methods:
        # Get details + Disease
        # Update details + Disease
        pass


class Doctor(Person):
    # Attrs: Person Attrs + Specialization
    # Methods:
        # Get details + Specialization
        # Update details + Specialization
    pass

class Appointment:
    # Attrs: ID, Patient, Doctor, Date
    # Methods:
        # Schedule appointment
        # Cancel appointment
        # Get appointment details
        # Update appointment details
    pass
