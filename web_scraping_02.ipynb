# %% [markdown]
# <a href="https://colab.research.google.com/github/abdel2ty/IntenseAI_Notebooks_v1/blob/main/web_scraping_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tutorial: Web Scraping with Python Using Beautiful Soup

# %% [markdown]
#         * We write a code that sends a request to the server that’s hosting the page we specified.
#         * The server will return the source code — HTML— for the page
#         * We can then parse the HTML to extract the data we want.

# %% [markdown]
# <center> <img src="response.png"> </center>

# %% [markdown]
# # Installing the required packages

# %%
# !pip install requests
# !pip install bs4

# %% [markdown]
# # Let's Start Scraping!

# %% [markdown]
#         * We’ll be using the Python library "requests" to send a request to the server and get the HTML code for the page.
#         * We’ll be using the Python library "Beautiful Soup" to parse the HTML code and extract the data we want.

# %%
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get('https://wuzzuf.net/search/jobs/?q=machine+learning&a=hpb')
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html lang="en" translate="no">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, shrink-to-fit=no" name="viewport"/>
# <meta content="Thu Dec 08 2022 18:30:44 GMT+0200" http-equiv="expires"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="cache-control"/>
# <meta content="notranslate" name="googlebot"/>
# <title data-react-helmet="true">42 machine learning jobs in Egypt – discover job details now on Wuzzuf!</title>
# <meta charset="utf-8" data-react-helmet="true"/><meta content="Explore 42 machine learning jobs in Egypt.  Apply for great job opportunities in leading companies with Wuzzuf today!" data-react-helmet="true" name="description"/><meta content="jobs in Egypt, job in Egypt, careers egypt, jobs in Cairo, jobs in alexandria, employment in egypt, Egypt jobs, jobs vacancies, job vacancies in egypt, job search egypt, job vacancies egypt, job recruitment in egypt, job opportunities in egypt, jobs cairo, job vacancy egypt , وظائف مصر" data-react-helmet="true" name="keywords"/><meta content="42 machine learning jobs in Egypt – discover job details now on Wuzzuf!" data-react-helmet="true" property="og:title"/><meta content="website" data-react-helmet="true" property="og:type"/><meta content="https://wuzzuf.net/search/jobs/" data-react-helmet="true" property="og:url"/><meta content="WUZZUF" data-react-helmet="true" property="og:site_name"/><meta content="373086796047717" data-react-helmet="true" property="fb:app_id"/><meta content="https://static.wuzzuf-data.net/search-page-og-image-bc0a066d44969c0f879dc5df1a6453f3.png" data-react-helmet="true" property="og:image"/><meta content="Explore 42 machine learning jobs in Egypt.  Apply for great job opportunities in leading companies with Wuzzuf today!" data-react-helmet="true" property="og:description"/><meta content="Maadi" data-react-helmet="true" property="og:locality"/><meta content="Cairo" data-react-helmet="true" property="og:region"/><meta content="Egypt" data-react-helmet="true" property="og:country-name"/>
# <link data-react-helmet="true" href="https://wuzzuf.net/search/jobs/" rel="canonical"/><link data-react-helmet="true" href="https://wuzzuf.net/search/jobs?q=machine%20learning&amp;start=1" rel="next"/><link data-react-helmet="true" href="https://wuzzuf.net/search/jobs/" hreflang="en-EG" rel="alternate"/><link data-react-helmet="true" href="https://wuzzuf.net/saudi/search/jobs/" hreflang="en-SA" rel="alternate"/>
# <link href="/manifest.json" rel="manifest"/>
# <link href="https://wuzzuf.net/favicon.ico" rel="icon"/>
# <link as="script" data-chunk="index" href="https://static.wuzzuf-data.net/vendor-1752747149792.c0359e6c4dac3e799e4a.js" rel="preload"/>
# <link as="script" data-chunk="index" href="https://static.wuzzuf-data.net/index-1752747149792.1fc9d99aac19d4c7cb60.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/7791-1752747149792.0bd8a67e84eb93b3bc93.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/7603-1752747149792.3dd87b0daa5eaf99ac5e.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/3724-1752747149792.f818dd47438b7edef08c.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/9778-1752747149792.5e3c349d46e625846833.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/4571-1752747149792.ed7c0975286ae8763afa.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/6334-1752747149792.0183e01511bcac49574f.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/4688-1752747149792.54941288cc41d4998058.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/2195-1752747149792.c1624b79ae60153308a3.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/8152-1752747149792.97a292dc44fcc50fc97d.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/911-1752747149792.b3084938c0b0a98b4613.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/6240-1752747149792.35e2979a2cf4c5d5ccd3.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/8310-1752747149792.335c638a1f6d35c8a8cd.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/1042-1752747149792.c02ba8d2a66ca36f6996.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/5746-1752747149792.379da372d2f794f93a80.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/4772-1752747149792.6cacea8ef588c34d03de.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/3411-1752747149792.58f48e1eaf01cadd67a9.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/2810-1752747149792.ee895e267dff60f29c32.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/1238-1752747149792.9301e621885b885bf68d.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/2025-1752747149792.ad505927bf5b224a54a5.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/9336-1752747149792.2febb9104c400f90e446.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/129-1752747149792.bea48c2eba8d819418fb.js" rel="preload"/>
# <link as="script" data-chunk="guest-job-search" href="https://static.wuzzuf-data.net/guest-job-search-1752747149792.ac4bc20ac546c6541f89.js" rel="preload"/>
# <link as="script" data-chunk="job-search-components-job-search-page-search-bar-card-desktop" href="https://static.wuzzuf-data.net/6016-1752747149792.40a9cc9f3987bdd43846.js" rel="preload"/>
# <link as="script" data-chunk="job-search-components-job-search-page-search-bar-card-desktop" href="https://static.wuzzuf-data.net/2571-1752747149792.7989ce401ed62afb9461.js" rel="preload"/>
# <link as="script" data-chunk="job-search-components-job-search-page-search-bar-card-desktop" href="https://static.wuzzuf-data.net/9718-1752747149792.36caa9f977306d2bc5a0.js" rel="preload"/>
# <link as="script" data-chunk="job-search-components-job-search-page-search-bar-card-desktop" href="https://static.wuzzuf-data.net/job-search-components-job-search-page-search-bar-card-desktop-1752747149792.50f0abe30d5301a3426a.js" rel="preload"/>
# <link as="style" href="https://fonts.googleapis.com/css?family=Open+Sans:300,300i,400,400i,600,600i,700,700i&amp;display=swap" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
# <noscript><link href="https://fonts.googleapis.com/css?family=Open+Sans:300,300i,400,400i,600,600i,700,700i&amp;display=swap" rel="stylesheet"/></noscript>
# <style>
#         html, body { padding: 0; margin: 0; font-family: 'Open Sans', sans-serif; }
#         input, textarea, select, button { font-family: 'Open Sans', sans-serif; }
#         * { box-sizing: border-box; }
#     </style>
# <link href="https://static.wuzzuf-data.net/css/global.css" media="print" onload="this.onload=null;this.rel='stylesheet';this.media='all'" rel="stylesheet"/>
# <link href="https://static.wuzzuf-data.net/css/lib.css" media="print" onload="this.onload=null;this.rel='stylesheet';this.media='all'" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-T4Z552" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <div id="app"><div><style data-emotion="css 1jsz4vo">.css-1jsz4vo{height:62px;position:relative;}</style><div class="css-1jsz4vo"><style data-emotion="css 1605mlf">.css-1605mlf{z-index:9998;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;top:0;left:0;right:0;height:62px;width:100%;position:fixed;background-color:#ffffff;border-bottom:1px solid #D9DDE4;}</style><header class="css-1605mlf"><style data-emotion="css 1kqcve2">.css-1kqcve2{width:100%;max-width:1170px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;justify-content:space-between;padding:0 10px;}</style><div class="css-1kqcve2"><style data-emotion="css 3cyd2n">.css-3cyd2n{margin-right:24px;}</style><style data-emotion="css kimudi">.css-kimudi{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:start;-webkit-box-align:start;-ms-flex-align:start;align-items:start;position:relative;cursor:pointer;width:125px;margin-right:24px;}</style><a aria-label="navigate to wuzzuf home page" class="css-kimudi e19qcx5a0" href="/jobs/egypt"><style data-emotion="css 1d3w5wq">.css-1d3w5wq{width:100%;}</style><svg aria-labelledby="wuzzuf-logo" class="css-1d3w5wq" viewbox="0 0 125 20" xmlns="http://www.w3.org/2000/svg"><path d="M23.724.001h4.906L22.583 20H18.17L14.315 7.96 10.489 20H6.046L0 .001h4.936L8.793 12.32 12.587 0h3.61l3.671 12.319L23.724 0zm9.147 17.552c-1.604-1.63-2.406-3.823-2.406-6.577V.001h4.689v11.036c0 1.54.432 2.714 1.296 3.524.864.81 2.046 1.215 3.548 1.215 1.48 0 2.648-.405 3.502-1.215.853-.81 1.28-1.985 1.28-3.524V0h4.689v10.975c0 2.754-.792 4.947-2.376 6.577C45.51 19.184 43.145 20 39.998 20s-5.523-.815-7.127-2.446zm18.416-.694L62.456 3.95H51.565V.001h16.69v3.17L57.15 16.052h11.106V20H51.287v-3.14zm18.803 0L81.258 3.95h-10.89V.001h16.69v3.17l-11.106 12.88h11.106v3.948H70.09v-3.14zm21.226.694c-1.605-1.63-2.407-3.823-2.407-6.577V.001h4.69v11.036c0 1.54.432 2.714 1.295 3.524.864.81 2.047 1.215 3.548 1.215 1.481 0 2.648-.405 3.502-1.215.853-.81 1.28-1.985 1.28-3.524V0h4.69v10.975c0 2.754-.793 4.947-2.376 6.577-1.584 1.631-3.949 2.446-7.096 2.446-3.147 0-5.522-.815-7.126-2.446zm23.279-5.733V20h-4.69V0H125l-1.08 3.982h-9.325V8.18h7.959l-.99 3.64h-6.97z" fill="#0055D9"></path></svg></a><div class="css-0"><style data-emotion="css sxw4a6">.css-sxw4a6{font-size:15px;font-weight:600;-webkit-text-decoration:none;text-decoration:none;margin-right:12px;padding:12px;cursor:pointer;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#405678;}.css-sxw4a6:hover{color:#0055D9;}.css-sxw4a6:hover path{fill:#0055D9;}.css-sxw4a6:hover div{border-top:5px solid #0055D9;}</style><a class="css-sxw4a6" href="#">Browse Jobs<style data-emotion="css 1q4vxyr">.css-1q4vxyr{margin-left:8px;}</style><style data-emotion="css ks9dan">.css-ks9dan{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;line-height:1em;width:16px;height:16px;margin-left:8px;}</style><i class="css-ks9dan efou2fk0" size="16"><svg height="16" preserveaspectratio="none" viewbox="0 0 24 24" width="16"><path d="M17.355 7.5L12 13.063 6.645 7.5 5 9.213l7 7.287 7-7.287z" fill="#334B6F"></path></svg></i></a></div><style data-emotion="css yujhzj">.css-yujhzj{-webkit-flex:2;-ms-flex:2;flex:2;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}</style><div class="css-yujhzj"><style data-emotion="css lo ...
# <script>
#         (function(){
#             var Wuzzuf = window.Wuzzuf = window.Wuzzuf || {};
#             Wuzzuf.country = {"country":"Egypt","countryId":"","subFolder":"","subFolderName":"egypt","defaultCountryQueryParams":"","capital":"Cairo","jobseekerHomePage":"\u002Fjobs\u002Fegypt","empHomePage":"\u002Frecruitment\u002Fegypt","hrefLang":"en-EG","viewerCountryIso":"eg"};
#             Wuzzuf.headers = {"host":"wuzzuf.net","x-real-ip":"40.0.1.185","x-forwarded-for":"156.193.43.196, 40.0.1.185","x-forwarded-proto":"http","connection":"close","x-request-id":"91e116086a97c4ca2dfbda56ab7edbeb","x-forwarded-host":"wuzzuf.net","x-forwarded-port":"80","x-forwarded-scheme":"http","x-scheme":"http","x-original-forwarded-for":"156.193.43.196, 18.68.32.55","x-amzn-trace-id":"Root=1-687b66c3-39fd235e0d51f03e3bf6f4a5","cloudfront-viewer-country":"EG","cloudfront-forwarded-proto":"https","cloudfront-is-desktop-viewer":"true","cloudfront-is-tablet-viewer":"false","cloudfront-viewer-asn":"8452","user-agent":"python-requests\u002F2.32.3","via":"1.1 aec01f265f362fdc0246b1de1723a19e.cloudfront.net (CloudFront)","x-amz-cf-id":"cDuPK4cGUEObvwQmJeV7Rq0BQo8sGUGIT1ICRdedd8cdpRbD2olSog==","cloudfront-is-smarttv-viewer":"false","cloudfront-is-mobile-viewer":"false","accept":"*\u002F*","accept-encoding":"gzip, deflate, br, zstd"};
#             Wuzzuf.isServerRendered = true;
#             Wuzzuf.initialStoreState = {"badges":{"landingPage":{"timestamp":null,"providers":null,"loading":false}},"browsingPage":{"sets":{},"metaTemplateType":{}},"communityPages":{"internship":{"jobs":{},"filters":{"isLoading":true,"isError":false,"error":null,"sets":{}},"hotJobs":null},"alexandria":{"jobs":{},"filters":{"isLoading":true,"isError":false,"error":null,"sets":{}},"hotJobs":null},"android":{"jobs":{},"filters":{"isLoading":true,"isError":false,"error":null,"sets":{}},"hotJobs":null},"pharmaceutical":{"jobs":{},"filters":{"isLoading":true,"isError":false,"error":null,"sets":{}},"hotJobs":null},"workFromHome":{"jobs":{},"filters":{"isLoading":true,"isError":false,"error":null,"sets":{}},"hotJobs":null},"startups":{"jobs":{},"filters":{"isLoading":true,"isError":false,"error":null,"sets":{}},"hotJobs":null}},"entities":{"companyPlanBenefit":{"isLoading":false,"collection":{},"error":null,"timestamp":null},"applicationStatistics":{"isLoading":false,"collection":{},"error":null,"timestamp":null},"badge":{"isLoading":false,"collection":{},"error":null,"timestamp":null},"badgeGradeDetails":{"isLoading":false,"collection":{},"error":null,"timestamp":null},"company":{"collection":{"2056":{"id":"2056","type":"company","attributes":{"uniqueId":"c69fd7e7-9373-11ea-add1-062a4819e772","name":"Egabi FSI","legalName":null,"logo":"Egabi-FSI-Egypt-2056-1597157894.png","slug":"egabi-solution-Egypt-2056","description":"Egabi FSI With 16+ years of experience enabling financial institutions of varying sizes and complexity across the MENA region to realize their true potential and focus on driving their business operations effectively and efficiently, egabiFSI is the go to partner of choice for banks, insurance companies, Microfinance & mortgage lending institutions who seek to automate their business. With diverse solutions that cover the entire spectrum of operational excellence across different business areas as well as analytical tools and business insight solutions.\n\nSpecialties\nCore Banking, MicroFinance, Islamic Banking, Mortgage, Profitability analysis and FTP, Risk Management, IFRS, Compliance and AML, Blockchain, Chatbot & AI, Cheque Clearing, Leasing, Factoring, Digital Banking, and Oracle Technology\n\nWhat we are offer;\n\nCompetitive monthly salary.\nSocial\u002F Family Health insurance (We bear it entirely).\nGreat Place to work located in Sheraton with unlimited drinks.\nAwesome Team, we have the best team that is supportive, collaborative, professional and fun.","specialties":[],"hiringFor":null,"website":"http:\u002F\u002Fegabifsi.com\u002F","facebookPage":"https:\u002F\u002Fwww.facebook.com\u002FegabiFSI","twitterAccount":null,"linkedinProfile":"https:\u002F\u002Fwww.linkedin.com\u002Fcompany\u002F18523982\u002F","blog":null,"onlinePresence":{"facebook":"https:\u002F\u002Fwww.facebook.com\u002FegabiFSI","twitter":null,"linkedin":"https:\u002F\u002Fwww.linkedin.com\u002Fcompany\u002F18523982\u002F","blog":null,"website":"http:\u002F\u002Fegabifsi.com\u002F","instagram":null,"youtube":null,"vimeo":null,"behance":null},"establishedYear":"2006","uniqueName":"Egabi FSI -w- 2056","taxId":null,"street":"الخليلي مربع 1149 مساكن شيراتون مصر الجديدة","isPersonal":false,"buildingNumber":"7","area":null,"publicStatus":{"id":1,"name":"Verified"},"statusUpdatedAt":null,"createdAt":"12\u002F27\u002F2012 11:06:18","perks":[]},"links":{"self":"https:\u002F\u002Fwuzzuf.net\u002Fapi\u002Fcompany\u002F2056","defaultLogoUrl":"https:\u002F\u002Fimages.wuzzuf-data.net\u002Ffiles\u002Fcompany_logo\u002FEgabi-FSI-Egypt-2056-1597157894.png","orgLogoUrl":"https:\u002F\u002Fimages.wuzzuf-data.net\u002Ffiles\u002Fcompany_logo\u002FEgabi-FSI-Egypt-2056-1597157894-org.png","smLogoUrl":"https:\u002F\u002Fimages.wuzzuf-data.net\u002Ffiles\u002Fcompany_logo\u002FEgabi-FSI-Egypt-2056-1597157894-sm.png","xsLogoUrl":"https:\u002F\u002Fimages.wuzzuf-data.net\u002Ffiles\u002Fcompany_logo\u002FEgabi-FSI-Egypt-2056-1597157894-xs.png","ogLogoUrl":"http ...
#             Wuzzuf.serverRenderedURL = "/search/jobs/?q=machine+learning&a=hpb";
#             Wuzzuf.userType = "guest";
#         }());
#     </script>
# <script>
#         window.addEventListener('beforeinstallprompt', function(){
#             e.preventDefault();
#         });
#     </script>
# <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">[7791,7603,3724,9778,4571,6334,4688,2195,8152,911,6240,8310,1042,5746,4772,3411,2810,1238,2025,9336,129,9621,6016,2571,9718,6677]</script><script id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">{"namedChunks":["guest-job-search","job-search-components-job-search-page-search-bar-card-desktop"]}</script>
# <script data-chunk="index" defer="" src="https://static.wuzzuf-data.net/vendor-1752747149792.c0359e6c4dac3e799e4a.js"></script>
# <script data-chunk="index" defer="" src="https://static.wuzzuf-data.net/index-1752747149792.1fc9d99aac19d4c7cb60.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/7791-1752747149792.0bd8a67e84eb93b3bc93.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/7603-1752747149792.3dd87b0daa5eaf99ac5e.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/3724-1752747149792.f818dd47438b7edef08c.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/9778-1752747149792.5e3c349d46e625846833.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/4571-1752747149792.ed7c0975286ae8763afa.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/6334-1752747149792.0183e01511bcac49574f.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/4688-1752747149792.54941288cc41d4998058.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/2195-1752747149792.c1624b79ae60153308a3.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/8152-1752747149792.97a292dc44fcc50fc97d.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/911-1752747149792.b3084938c0b0a98b4613.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/6240-1752747149792.35e2979a2cf4c5d5ccd3.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/8310-1752747149792.335c638a1f6d35c8a8cd.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/1042-1752747149792.c02ba8d2a66ca36f6996.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/5746-1752747149792.379da372d2f794f93a80.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/4772-1752747149792.6cacea8ef588c34d03de.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/3411-1752747149792.58f48e1eaf01cadd67a9.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/2810-1752747149792.ee895e267dff60f29c32.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/1238-1752747149792.9301e621885b885bf68d.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/2025-1752747149792.ad505927bf5b224a54a5.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/9336-1752747149792.2febb9104c400f90e446.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/129-1752747149792.bea48c2eba8d819418fb.js"></script>
# <script data-chunk="guest-job-search" defer="" src="https://static.wuzzuf-data.net/guest-job-search-1752747149792.ac4bc20ac546c6541f89.js"></script>
# <script data-chunk="job-search-components-job-search-page-search-bar-card-desktop" defer="" src="https://static.wuzzuf-data.net/6016-1752747149792.40a9cc9f3987bdd43846.js"></script>
# <script data-chunk="job-search-components-job-search-page-search-bar-card-desktop" defer="" src="https://static.wuzzuf-data.net/2571-1752747149792.7989ce401ed62afb9461.js"></script>
# <script data-chunk="job-search-components-job-search-page-search-bar-card-desktop" defer="" src="https://static.wuzzuf-data.net/9718-1752747149792.36caa9f977306d2bc5a0.js"></script>
# <script data-chunk="job-search-components-job-search-page-search-bar-card-desktop" defer="" src="https://static.wuzzuf-data.net/job-search-components-job-search-page-search-bar-card-desktop-1752747149792.50f0abe30d5301a3426a.js"></script>
# <script data-cf-beacon='{"token": "c0ca6af573dc4cd5973fdbdea3c92282"}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js"></script>
# </body>
# </html>

# %%
title = soup.find("h2", {'class': 'css-m604qf'})
title
# Out:
# <h2 class="css-m604qf"><style data-emotion="css o171kl">.css-o171kl{-webkit-text-decoration:none;text-decoration:none;color:inherit;}</style><a class="css-o171kl" href="https://wuzzuf.net/jobs/p/8oulgynroyag-data-scientist-egabi-fsi-cairo-egypt" rel="noreferrer" target="_blank">Data Scientist</a></h2>

# %%
title.a.text
# Out:
# 'Data Scientist'

# %%
titles = soup.find_all("h2", {'class': 'css-m604qf'})
titles
# Out:
# [<h2 class="css-m604qf"><style data-emotion="css o171kl">.css-o171kl{-webkit-text-decoration:none;text-decoration:none;color:inherit;}</style><a class="css-o171kl" href="https://wuzzuf.net/jobs/p/8oulgynroyag-data-scientist-egabi-fsi-cairo-egypt" rel="noreferrer" target="_blank">Data Scientist</a></h2>,
#  <h2 class="css-m604qf"><a class="css-o171kl" href="https://wuzzuf.net/jobs/p/qgconbaaa2gf-ai-engineer-provision-group-cairo-egypt" rel="noreferrer" target="_blank">AI Engineer</a></h2>,
#  <h2 class="css-m604qf"><a class="css-o171kl" href="https://wuzzuf.net/jobs/p/bu1ksr9tke5x-data-scientist-lumin-giza-egypt" rel="noreferrer" target="_blank">Data Scientist</a></h2>,
#  <h2 class="css-m604qf"><a class="css-o171kl" href="https://wuzzuf.net/internship/2tshmlfj3ha9-graduate-internship-enterprise-software-engineering-et3-tomorrow-information-technology-cairo-egypt" rel="noreferrer" target="_blank">Graduate Internship: Enterprise Software Engineering</a></h2>,
#  <h2 class="css-m604qf"><a class="css-o171kl" href="https://wuzzuf.net/jobs/p/gofovnetfvvf-ai-engineer-computer-vision-speech-nlp-generative-ai-madar-soft-alexandria-egypt" rel="noreferrer" target="_blank">AI Engineer (Computer Vision, Speech, NLP &amp; Generative AI)</a></h2>,
#  <h2 class="css-m604qf"><a class="css-o171kl" href="https://wuzzuf.net/jobs/p/cfylkx2k6qh2-ai-engineer-custom-ai-solutions-gpt-tools-–-on-site-stellar-charter-nexus-cairo-egypt" rel="noreferrer" target="_blank">AI Engineer (Custom AI Solutions &amp; GPT Tools) – On-Site</a></h2>,
#  <h2 class="css-m604qf"><a class="css-o171kl" href="https://wuzzuf.net/jobs/p/mgyqxkoukqrd-3d-printer-maintenance-technician-gazelle-3d-tech-giza-egypt" rel="noreferrer" target="_blank">3D Printer Maintenance Technician</a></h2>,
#  <h2 class="css-m604qf"><a class="css-o171kl" href="https://wuzzuf.net/jobs/p/jQuD5uCDAOds-Senior-AI-Engineer-Lumin-Giza-Egypt" rel="noreferrer" target="_blank">Senior AI Engineer</a></h2>,
#  <h2 class="css-m604qf"><a class="css-o171kl" href="https://wuzzuf.net/jobs/p/kbzexl37bjxb-senior-data-analyst-xceed-contact-center-cairo-egypt" rel="noreferrer" target="_blank">Senior Data Analyst</a></h2>,
#  <h2 class="css-m604qf"><a class="css-o171kl" href="https://wuzzuf.net/jobs/p/id9koixxt5zx-senior-ai-engineer-link-development-cairo-egypt" rel="noreferrer" target="_blank">Senior AI Engineer</a></h2>,
#  <h2 class="css-m604qf"><a class="css-o171kl" href="https://wuzzuf.net/jobs/p/6usftpppfu2x-software-development-manager-giza-egypt" rel="noreferrer" target="_blank">Software Development Manager</a></h2>,
#  <h2 class="css-m604qf"><a class="css-o171kl" href="https://wuzzuf.net/jobs/p/8cbxjq8papt4-textile-engineer-lotus-tex-sharqia-egypt" rel="noreferrer" target="_blank">Textile Engineer</a></h2>,
#  <h2 class="css-m604qf"><a class="css-o171kl" href="https://wuzzuf.net/jobs/p/btahdzswqdgs-senior-cost-accountant-manufacturing-industry-selah-eltelmeez-for-publishing-printing-cairo-egypt" rel="noreferrer" target="_blank">Senior Cost Accountant (Manufacturing Industry)</a></h2>,
#  <h2 class="css-m604qf"><a class="css-o171kl" href="https://wuzzuf.net/jobs/p/x9ma4minmoqm-ai-engineering-manager-link-development-cairo-egypt" rel="noreferrer" target="_blank">AI Engineering Manager</a></h2>,
#  <h2 class="css-m604qf"><a class="css-o171kl" href="https://wuzzuf.net/jobs/p/g/wovnlx6nn74u-research-scientist-ai-interactome-genbio-ai-dubai-united-arab-emirates" rel="noreferrer" target="_blank">Research Scientist (AI) - Interactome</a></h2>]

# %%
titles[0]
# Out:
# <h2 class="css-m604qf"><style data-emotion="css o171kl">.css-o171kl{-webkit-text-decoration:none;text-decoration:none;color:inherit;}</style><a class="css-o171kl" href="https://wuzzuf.net/jobs/p/8oulgynroyag-data-scientist-egabi-fsi-cairo-egypt" rel="noreferrer" target="_blank">Data Scientist</a></h2>

# %%
titles[0].text
# Out:
# 'Data Scientist'

# %%
for title in titles:
    print(title.text)
# Out:
# Data Scientist
# AI Engineer
# Data Scientist
# Graduate Internship: Enterprise Software Engineering
# AI Engineer (Computer Vision, Speech, NLP & Generative AI)
# AI Engineer (Custom AI Solutions & GPT Tools) – On-Site
# 3D Printer Maintenance Technician
# Senior AI Engineer
# Senior Data Analyst
# Senior AI Engineer
# Software Development Manager
# Textile Engineer
# Senior Cost Accountant (Manufacturing Industry)
# AI Engineering Manager
# Research Scientist (AI) - Interactome

# %%
titles_lst = [title.a.text for title in titles]
titles_lst
# Out:
# ['Data Scientist',
#  'AI Engineer',
#  'Data Scientist',
#  'Graduate Internship: Enterprise Software Engineering',
#  'AI Engineer (Computer Vision, Speech, NLP & Generative AI)',
#  'AI Engineer (Custom AI Solutions & GPT Tools) – On-Site',
#  '3D Printer Maintenance Technician',
#  'Senior AI Engineer',
#  'Senior Data Analyst',
#  'Senior AI Engineer',
#  'Software Development Manager',
#  'Textile Engineer',
#  'Senior Cost Accountant (Manufacturing Industry)',
#  'AI Engineering Manager',
#  'Research Scientist (AI) - Interactome']

# %%
titles[0].a['href']
# Out:
# 'https://wuzzuf.net/jobs/p/8oulgynroyag-data-scientist-egabi-fsi-cairo-egypt'

# %%
'https://wuzzuf.net'+titles[0].a['href']
# Out:
# 'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/8oulgynroyag-data-scientist-egabi-fsi-cairo-egypt'

# %%
links = ['https://wuzzuf.net' + title.a['href'] for title in titles]
links
# Out:
# ['https://wuzzuf.nethttps://wuzzuf.net/jobs/p/8oulgynroyag-data-scientist-egabi-fsi-cairo-egypt',
#  'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/qgconbaaa2gf-ai-engineer-provision-group-cairo-egypt',
#  'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/bu1ksr9tke5x-data-scientist-lumin-giza-egypt',
#  'https://wuzzuf.nethttps://wuzzuf.net/internship/2tshmlfj3ha9-graduate-internship-enterprise-software-engineering-et3-tomorrow-information-technology-cairo-egypt',
#  'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/gofovnetfvvf-ai-engineer-computer-vision-speech-nlp-generative-ai-madar-soft-alexandria-egypt',
#  'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/cfylkx2k6qh2-ai-engineer-custom-ai-solutions-gpt-tools-–-on-site-stellar-charter-nexus-cairo-egypt',
#  'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/mgyqxkoukqrd-3d-printer-maintenance-technician-gazelle-3d-tech-giza-egypt',
#  'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/jQuD5uCDAOds-Senior-AI-Engineer-Lumin-Giza-Egypt',
#  'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/kbzexl37bjxb-senior-data-analyst-xceed-contact-center-cairo-egypt',
#  'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/id9koixxt5zx-senior-ai-engineer-link-development-cairo-egypt',
#  'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/6usftpppfu2x-software-development-manager-giza-egypt',
#  'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/8cbxjq8papt4-textile-engineer-lotus-tex-sharqia-egypt',
#  'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/btahdzswqdgs-senior-cost-accountant-manufacturing-industry-selah-eltelmeez-for-publishing-printing-cairo-egypt',
#  'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/x9ma4minmoqm-ai-engineering-manager-link-development-cairo-egypt',
#  'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/g/wovnlx6nn74u-research-scientist-ai-interactome-genbio-ai-dubai-united-arab-emirates']

# %%
links = [('https://wuzzuf.net' + title.a['href']).replace(' ', '%20') for title in titles]
links
# Out:
# ['https://wuzzuf.nethttps://wuzzuf.net/jobs/p/8oulgynroyag-data-scientist-egabi-fsi-cairo-egypt',
#  'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/qgconbaaa2gf-ai-engineer-provision-group-cairo-egypt',
#  'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/bu1ksr9tke5x-data-scientist-lumin-giza-egypt',
#  'https://wuzzuf.nethttps://wuzzuf.net/internship/2tshmlfj3ha9-graduate-internship-enterprise-software-engineering-et3-tomorrow-information-technology-cairo-egypt',
#  'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/gofovnetfvvf-ai-engineer-computer-vision-speech-nlp-generative-ai-madar-soft-alexandria-egypt',
#  'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/cfylkx2k6qh2-ai-engineer-custom-ai-solutions-gpt-tools-–-on-site-stellar-charter-nexus-cairo-egypt',
#  'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/mgyqxkoukqrd-3d-printer-maintenance-technician-gazelle-3d-tech-giza-egypt',
#  'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/jQuD5uCDAOds-Senior-AI-Engineer-Lumin-Giza-Egypt',
#  'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/kbzexl37bjxb-senior-data-analyst-xceed-contact-center-cairo-egypt',
#  'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/id9koixxt5zx-senior-ai-engineer-link-development-cairo-egypt',
#  'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/6usftpppfu2x-software-development-manager-giza-egypt',
#  'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/8cbxjq8papt4-textile-engineer-lotus-tex-sharqia-egypt',
#  'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/btahdzswqdgs-senior-cost-accountant-manufacturing-industry-selah-eltelmeez-for-publishing-printing-cairo-egypt',
#  'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/x9ma4minmoqm-ai-engineering-manager-link-development-cairo-egypt',
#  'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/g/wovnlx6nn74u-research-scientist-ai-interactome-genbio-ai-dubai-united-arab-emirates']

# %%
occupations = soup.find_all("span", {'class': 'css-1ve4b75 eoyjyou0'})
occupations
# Out:
# [<span class="css-1ve4b75 eoyjyou0">Full Time</span>,
#  <span class="css-1ve4b75 eoyjyou0">Full Time</span>,
#  <span class="css-1ve4b75 eoyjyou0">Part Time</span>,
#  <span class="css-1ve4b75 eoyjyou0">Freelance / Project</span>,
#  <span class="css-1ve4b75 eoyjyou0">Full Time</span>,
#  <span class="css-1ve4b75 eoyjyou0">Internship</span>,
#  <span class="css-1ve4b75 eoyjyou0">Full Time</span>,
#  <span class="css-1ve4b75 eoyjyou0">Full Time</span>,
#  <span class="css-1ve4b75 eoyjyou0">Full Time</span>,
#  <span class="css-1ve4b75 eoyjyou0">Full Time</span>,
#  <span class="css-1ve4b75 eoyjyou0">Full Time</span>,
#  <span class="css-1ve4b75 eoyjyou0">Full Time</span>,
#  <span class="css-1ve4b75 eoyjyou0">Full Time</span>,
#  <span class="css-1ve4b75 eoyjyou0">Full Time</span>,
#  <span class="css-1ve4b75 eoyjyou0">Full Time</span>,
#  <span class="css-1ve4b75 eoyjyou0">Full Time</span>,
#  <span class="css-1ve4b75 eoyjyou0">Full Time</span>]

# %%
len(occupations)
# Out:
# 17

# %%
len(titles)
# Out:
# 15

# %%
occupations = soup.find_all("div", {'class': 'css-1lh32fc'})
occupations
# Out:
# [<div class="css-1lh32fc"><style data-emotion="css n2jc4m">.css-n2jc4m{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-text-decoration:none;text-decoration:none;color:inherit;margin-bottom:4px;}</style><a class="css-n2jc4m" href="/a/Full-Time-Jobs-in-Egypt"><style data-emotion="css adtuo7">.css-adtuo7{cursor:pointer;padding:0 4px;border-radius:4px;}</style><style data-emotion="css 1ve4b75">.css-1ve4b75{font-size:12px;font-weight:600;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;min-height:20px;margin-right:4px;border-radius:2px;max-width:196px;white-space:nowrap;overflow:hidden;cursor:default;text-overflow:ellipsis;padding:2px 4px;background-color:#EBEDF0;color:#001433;cursor:pointer;padding:0 4px;border-radius:4px;}</style><span class="css-1ve4b75 eoyjyou0">Full Time</span></a><a href="/a/On-Site-Jobs-in-Egypt"><style data-emotion="css 1i1n6hw">.css-1i1n6hw{cursor:pointer;padding:0 4px;border-radius:4px;margin-bottom:4px;}</style><style data-emotion="css o1vzmt">.css-o1vzmt{font-size:12px;font-weight:600;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;min-height:20px;margin-right:4px;border-radius:2px;max-width:196px;white-space:nowrap;overflow:hidden;cursor:default;text-overflow:ellipsis;padding:2px 4px;background-color:#EBEDF0;color:#001433;cursor:pointer;padding:0 4px;border-radius:4px;margin-bottom:4px;}</style><span class="css-o1vzmt eoyjyou0">On-site</span></a></div>,
#  <div class="css-1lh32fc"><a class="css-n2jc4m" href="/a/Full-Time-Jobs-in-Egypt"><span class="css-1ve4b75 eoyjyou0">Full Time</span></a><a class="css-n2jc4m" href="/a/Part-Time-Jobs-in-Egypt"><span class="css-1ve4b75 eoyjyou0">Part Time</span></a><a class="css-n2jc4m" href="/a/Freelance-Project-Jobs-in-Egypt"><span class="css-1ve4b75 eoyjyou0">Freelance / Project</span></a><a href="/a/Hybrid-Jobs-in-Egypt"><span class="css-o1vzmt eoyjyou0">Hybrid</span></a></div>,
#  <div class="css-1lh32fc"><a class="css-n2jc4m" href="/a/Full-Time-Jobs-in-Egypt"><span class="css-1ve4b75 eoyjyou0">Full Time</span></a><a href="/a/Hybrid-Jobs-in-Egypt"><span class="css-o1vzmt eoyjyou0">Hybrid</span></a></div>,
#  <div class="css-1lh32fc"><a class="css-n2jc4m" href="/a/Internship-Jobs-in-Egypt"><span class="css-1ve4b75 eoyjyou0">Internship</span></a><a href="/a/Hybrid-Jobs-in-Egypt"><span class="css-o1vzmt eoyjyou0">Hybrid</span></a></div>,
#  <div class="css-1lh32fc"><a class="css-n2jc4m" href="/a/Full-Time-Jobs-in-Egypt"><span class="css-1ve4b75 eoyjyou0">Full Time</span></a><a href="/a/Remote-Jobs-in-Egypt"><span class="css-o1vzmt eoyjyou0">Remote</span></a></div>,
#  <div class="css-1lh32fc"><a class="css-n2jc4m" href="/a/Full-Time-Jobs-in-Egypt"><span class="css-1ve4b75 eoyjyou0">Full Time</span></a><a href="/a/On-Site-Jobs-in-Egypt"><span class="css-o1vzmt eoyjyou0">On-site</span></a></div>,
#  <div class="css-1lh32fc"><a class="css-n2jc4m" href="/a/Full-Time-Jobs-in-Egypt"><span class="css-1ve4b75 eoyjyou0">Full Time</span></a><a href="/a/On-Site-Jobs-in-Egypt"><span class="css-o1vzmt eoyjyou0">On-site</span></a></div>,
#  <div class="css-1lh32fc"><a class="css-n2jc4m" href="/a/Full-Time-Jobs-in-Egypt"><span class="css-1ve4b75 eoyjyou0">Full Time</span></a><a href="/a/Hybrid-Jobs-in-Egypt"><span class="css-o1vzmt eoyjyou0">Hybrid</span></a></div>,
#  <div class="css-1lh32fc"><a class="css-n2jc4m" href="/a/Full-Time-Jobs-in-Egypt"><span class="css-1ve4b75 eoyjyou0">Full Time</span></a><a href="/a/On-Site-Jobs-in-Egypt"><span class="css-o1vzmt eoyjyou0">On-site</span></a></div>,
#  <div class="css-1lh32fc"><a class="css-n2jc4m" href="/a/Full-Time-Jobs-in-Egypt"><span class="css-1ve4b75 eoyjyou0">Full Time</span></a><a href="/a/Hybrid-Jobs-in-Egypt"><span class="css-o1vzmt eoyjyou0">Hybrid</span></a></div>,
#  <div class="css-1lh32fc"><a class="css-n2jc4m" href="/a/Full-Time-Jobs-in-Egypt"><span class="css-1ve4b75 eoyjyou0">Full Time</span></a><a href="/a/Hybrid-Jobs-in-Egypt"><span class="css-o1vzmt eoyjyou0">Hybrid</span></a></div>,
#  <div class="css-1lh32fc"><a class="css-n2jc4m" href="/a/Full-Time-Jobs-in-Egypt"><span class="css-1ve4b75 eoyjyou0">Full Time</span></a><a href="/a/On-Site-Jobs-in-Egypt"><span class="css-o1vzmt eoyjyou0">On-site</span></a></div>,
#  <div class="css-1lh32fc"><a class="css-n2jc4m" href="/a/Full-Time-Jobs-in-Egypt"><span class="css-1ve4b75 eoyjyou0">Full Time</span></a><a href="/a/On-Site-Jobs-in-Egypt"><span class="css-o1vzmt eoyjyou0">On-site</span></a></div>,
#  <div class="css-1lh32fc"><a class="css-n2jc4m" href="/a/Full-Time-Jobs-in-Egypt"><span class="css-1ve4b75 eoyjyou0">Full Time</span></a><a href="/a/Hybrid-Jobs-in-Egypt"><span class="css-o1vzmt eoyjyou0">Hybrid</span></a></div>,
#  <div class="css-1lh32fc"><a class="css-n2jc4m" href="/a/Full-Time-Jobs-in-United-Arab-Emirates"><span class="css-1ve4b75 eoyjyou0">Full Time</span></a></div>]

# %%
occupations[0]
# Out:
# <div class="css-1lh32fc"><style data-emotion="css n2jc4m">.css-n2jc4m{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-text-decoration:none;text-decoration:none;color:inherit;margin-bottom:4px;}</style><a class="css-n2jc4m" href="/a/Full-Time-Jobs-in-Egypt"><style data-emotion="css adtuo7">.css-adtuo7{cursor:pointer;padding:0 4px;border-radius:4px;}</style><style data-emotion="css 1ve4b75">.css-1ve4b75{font-size:12px;font-weight:600;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;min-height:20px;margin-right:4px;border-radius:2px;max-width:196px;white-space:nowrap;overflow:hidden;cursor:default;text-overflow:ellipsis;padding:2px 4px;background-color:#EBEDF0;color:#001433;cursor:pointer;padding:0 4px;border-radius:4px;}</style><span class="css-1ve4b75 eoyjyou0">Full Time</span></a><a href="/a/On-Site-Jobs-in-Egypt"><style data-emotion="css 1i1n6hw">.css-1i1n6hw{cursor:pointer;padding:0 4px;border-radius:4px;margin-bottom:4px;}</style><style data-emotion="css o1vzmt">.css-o1vzmt{font-size:12px;font-weight:600;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;min-height:20px;margin-right:4px;border-radius:2px;max-width:196px;white-space:nowrap;overflow:hidden;cursor:default;text-overflow:ellipsis;padding:2px 4px;background-color:#EBEDF0;color:#001433;cursor:pointer;padding:0 4px;border-radius:4px;margin-bottom:4px;}</style><span class="css-o1vzmt eoyjyou0">On-site</span></a></div>

# %%
occupations[0].text
# Out:
# 'Full TimeOn-site'

# %%
occupations[1].text
# Out:
# 'Full TimePart TimeFreelance / ProjectHybrid'

# %%
occupations[0].text[:9] + '/' + occupations[0].text[9:]
# Out:
# 'Full Time/On-site'

# %%
occupations_lst = [occupation.text for occupation in occupations]
occupations_lst
# Out:
# ['Full TimeOn-site',
#  'Full TimePart TimeFreelance / ProjectHybrid',
#  'Full TimeHybrid',
#  'InternshipHybrid',
#  'Full TimeRemote',
#  'Full TimeOn-site',
#  'Full TimeOn-site',
#  'Full TimeHybrid',
#  'Full TimeOn-site',
#  'Full TimeHybrid',
#  'Full TimeHybrid',
#  'Full TimeOn-site',
#  'Full TimeOn-site',
#  'Full TimeHybrid',
#  'Full Time']

# %%
companies = soup.find_all("a", {'class': 'css-17s97q8'})
companies
# Out:
# [<a class="css-17s97q8" href="https://wuzzuf.net/jobs/careers/egabi-solution-Egypt-2056" rel="noreferrer" target="_blank">Egabi FSI -</a>,
#  <a class="css-17s97q8" href="https://wuzzuf.net/jobs/careers/ProVision-Group-Egypt-10789" rel="noreferrer" target="_blank">ProVision Group -</a>,
#  <a class="css-17s97q8" href="https://wuzzuf.net/jobs/careers/Excel-Systems-LLC-Egypt-13729" rel="noreferrer" target="_blank">Lumin -</a>,
#  <a class="css-17s97q8" href="https://wuzzuf.net/jobs/careers/eT3---Tomorrow-Information-Technology-Egypt-5525" rel="noreferrer" target="_blank">eT3 - Tomorrow Information Technology -</a>,
#  <a class="css-17s97q8" href="https://wuzzuf.net/jobs/careers/Madar-Soft-Egypt-14834" rel="noreferrer" target="_blank">Madar Soft -</a>,
#  <a class="css-17s97q8" href="https://wuzzuf.net/jobs/careers/stellar-charter-nexus-egypt-128136" rel="noreferrer" target="_blank">Stellar Charter Nexus -</a>,
#  <a class="css-17s97q8" href="https://wuzzuf.net/jobs/careers/Gazelle-3D-Tech-Egypt-62526" rel="noreferrer" target="_blank">Gazelle 3D Tech -</a>,
#  <a class="css-17s97q8" href="https://wuzzuf.net/jobs/careers/Excel-Systems-LLC-Egypt-13729" rel="noreferrer" target="_blank">Lumin -</a>,
#  <a class="css-17s97q8" href="https://wuzzuf.net/jobs/careers/XCEEDCC-Egypt-52679" rel="noreferrer" target="_blank">Xceed Contact Center -</a>,
#  <a class="css-17s97q8" href="https://wuzzuf.net/jobs/careers/Link-Development-Egypt-15576" rel="noreferrer" target="_blank">Link Development -</a>,
#  <a class="css-17s97q8" rel="noreferrer" target="_blank">Confidential -</a>,
#  <a class="css-17s97q8" href="https://wuzzuf.net/jobs/careers/Lotus Tex-Egypt-125326" rel="noreferrer" target="_blank">Lotus Tex  -</a>,
#  <a class="css-17s97q8" href="https://wuzzuf.net/jobs/careers/Selah-ElTelmeez-For-Publishing---printing-Egypt-31447" rel="noreferrer" target="_blank">Selah ElTelmeez For Publishing &amp; printing -</a>,
#  <a class="css-17s97q8" href="https://wuzzuf.net/jobs/careers/Link-Development-Egypt-15576" rel="noreferrer" target="_blank">Link Development -</a>,
#  <a class="css-17s97q8" href="https://wuzzuf.net/jobs/careers/genbio-ai-united-arab-emirates-127690" rel="noreferrer" target="_blank">GenBio AI -</a>]

# %%
companies_lst = [company.text for company in companies]
companies_lst
# Out:
# ['Egabi FSI -',
#  'ProVision Group -',
#  'Lumin -',
#  'eT3 - Tomorrow Information Technology -',
#  'Madar Soft -',
#  'Stellar Charter Nexus -',
#  'Gazelle 3D Tech -',
#  'Lumin -',
#  'Xceed Contact Center -',
#  'Link Development -',
#  'Confidential -',
#  'Lotus Tex  -',
#  'Selah ElTelmeez For Publishing & printing -',
#  'Link Development -',
#  'GenBio AI -']

# %%
companies_lst = [company.replace(' -', '') for company in companies_lst]
companies_lst
# Out:
# ['Egabi FSI',
#  'ProVision Group',
#  'Lumin',
#  'eT3 Tomorrow Information Technology',
#  'Madar Soft',
#  'Stellar Charter Nexus',
#  'Gazelle 3D Tech',
#  'Lumin',
#  'Xceed Contact Center',
#  'Link Development',
#  'Confidential',
#  'Lotus Tex ',
#  'Selah ElTelmeez For Publishing & printing',
#  'Link Development',
#  'GenBio AI']

# %%
specs = soup.find_all("div", {'class': 'css-y4udm8'})
specs[2].text
# Out:
# 'Full TimeHybridExperienced · 3+ Yrs of Exp · IT/Software Development · Analyst/Research · Engineering - Telecom/Technology · Computer Science · Analysis · Mathematics · Data Analysis · Hadoop · Data Science · Information Technology (IT)'

# %%
specs[2].text.split(' · ')
# Out:
# ['Full TimeHybridExperienced',
#  '3+ Yrs of Exp',
#  'IT/Software Development',
#  'Analyst/Research',
#  'Engineering - Telecom/Technology',
#  'Computer Science',
#  'Analysis',
#  'Mathematics',
#  'Data Analysis',
#  'Hadoop',
#  'Data Science',
#  'Information Technology (IT)']

# %%
for spec in specs:
    print(len(spec.text.split(' · ')))
# Out:
# 12
# 7
# 12
# 11
# 12
# 12
# 7
# 12
# 12
# 12
# 12
# 8
# 12
# 12
# 11

# %%
specs_lst = [spec.text for spec in specs]
specs_lst
# Out:
# ['Full TimeOn-siteEntry Level · 1 - 4 Yrs of Exp · IT/Software Development · Engineering - Telecom/Technology · Computer Science · Data Mining · Data Science · data scientist · Hadoop · Machine Learning · Python · SQL',
#  'Full TimePart TimeFreelance / ProjectHybridExperienced · 2 - 7 Yrs of Exp · IT/Software Development · AI · Computer Vision · Data Science · Machine Learning',
#  'Full TimeHybridExperienced · 3+ Yrs of Exp · IT/Software Development · Analyst/Research · Engineering - Telecom/Technology · Computer Science · Analysis · Mathematics · Data Analysis · Hadoop · Data Science · Information Technology (IT)',
#  'InternshipHybridEntry Level · IT/Software Development · Computer Science · Software Development · Software Engineering · Computer Engineering · Back-End Development · Front-End Development · front-end web development · Software Testing · Data Engineering',
#  'Full TimeRemoteExperienced · 3 - 5 Yrs of Exp · IT/Software Development · Engineering - Telecom/Technology · computer · AI · NLP · Engineering · Information Technology (IT) · CUDA · Linux · Computer Science',
#  'Full TimeOn-siteExperienced · 2+ Yrs of Exp · IT/Software Development · Analyst/Research · Engineering - Telecom/Technology · AI · APIs · Computer Science · Development · Engineering · Frameworks · Information Technology (IT)',
#  'Full TimeOn-siteExperienced · 2+ Yrs of Exp · males_only · Installation/Maintenance/Repair · 3D Printing · Machines · Maintenance',
#  'Full TimeHybridExperienced · 3 - 5 Yrs of Exp · IT/Software Development · AI · Artificial Intelligence · Computer Vision · Machine Learning · TensorFlow · Python · Computer Science · Programming · PyTorch',
#  'Full TimeOn-siteExperienced · 3+ Yrs of Exp · Analyst/Research · Engineering - Telecom/Technology · ETL · Data Analysis · Communication skills · Python · SQL · Business Intelligence · PowerBI · Pandas',
#  'Full TimeHybridExperienced · 2 - 5 Yrs of Exp · IT/Software Development · Engineering - Telecom/Technology · Computer Science · BI · Software Engineering · SQL · Software Development · Power BI · SSRS · SQL Server',
#  'Full TimeHybridManager · 10+ Yrs of Exp · Business Development · IT/Software Development · Engineering - Telecom/Technology · Azure · Computer Science · developer · Engineering · ERP System · Information Technology (IT) · ERP',
#  'Full TimeOn-siteExperienced · 1 - 3 Yrs of Exp · males_only · Manufacturing/Production · Engineering - Other · Engineering · Textile · Production',
#  'Full TimeOn-siteExperienced · 4 - 6 Yrs of Exp · Accounting/Finance · Accounting · analytical · Communication · Cost Accounting · ERP System · Finance · Financial Management · Cost · ERP',
#  'Full TimeHybridManager · 5+ Yrs of Exp · IT/Software Development · Operations/Management · Engineering - Telecom/Technology · Computer Science · BI · Software Engineering · SQL · Software Development · Power BI · SSRS',
#  'Full TimeNot specified · IT/Software Development · Analyst/Research · Engineering - Telecom/Technology · computer science · information technology (it) · engineering · python · research · software engineering · machine learning']

# %%
scraped_data = {}
scraped_data['Title'] = titles_lst
scraped_data['Link'] = links
scraped_data['Occupation'] = occupations_lst
scraped_data['Company'] = companies_lst
scraped_data['Specs'] = specs_lst
scraped_data
# Out:
# {'Title': ['Data Scientist',
#   'AI Engineer',
#   'Data Scientist',
#   'Graduate Internship: Enterprise Software Engineering',
#   'AI Engineer (Computer Vision, Speech, NLP & Generative AI)',
#   'AI Engineer (Custom AI Solutions & GPT Tools) – On-Site',
#   '3D Printer Maintenance Technician',
#   'Senior AI Engineer',
#   'Senior Data Analyst',
#   'Senior AI Engineer',
#   'Software Development Manager',
#   'Textile Engineer',
#   'Senior Cost Accountant (Manufacturing Industry)',
#   'AI Engineering Manager',
#   'Research Scientist (AI) - Interactome'],
#  'Link': ['https://wuzzuf.nethttps://wuzzuf.net/jobs/p/8oulgynroyag-data-scientist-egabi-fsi-cairo-egypt',
#   'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/qgconbaaa2gf-ai-engineer-provision-group-cairo-egypt',
#   'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/bu1ksr9tke5x-data-scientist-lumin-giza-egypt',
#   'https://wuzzuf.nethttps://wuzzuf.net/internship/2tshmlfj3ha9-graduate-internship-enterprise-software-engineering-et3-tomorrow-information-technology-cairo-egypt',
#   'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/gofovnetfvvf-ai-engineer-computer-vision-speech-nlp-generative-ai-madar-soft-alexandria-egypt',
#   'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/cfylkx2k6qh2-ai-engineer-custom-ai-solutions-gpt-tools-–-on-site-stellar-charter-nexus-cairo-egypt',
#   'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/mgyqxkoukqrd-3d-printer-maintenance-technician-gazelle-3d-tech-giza-egypt',
#   'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/jQuD5uCDAOds-Senior-AI-Engineer-Lumin-Giza-Egypt',
#   'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/kbzexl37bjxb-senior-data-analyst-xceed-contact-center-cairo-egypt',
#   'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/id9koixxt5zx-senior-ai-engineer-link-development-cairo-egypt',
#   'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/6usftpppfu2x-software-development-manager-giza-egypt',
#   'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/8cbxjq8papt4-textile-engineer-lotus-tex-sharqia-egypt',
#   'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/btahdzswqdgs-senior-cost-accountant-manufacturing-industry-selah-eltelmeez-for-publishing-printing-cairo-egypt',
#   'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/x9ma4minmoqm-ai-engineering-manager-link-development-cairo-egypt',
#   'https://wuzzuf.nethttps://wuzzuf.net/jobs/p/g/wovnlx6nn74u-research-scientist-ai-interactome-genbio-ai-dubai-united-arab-emirates'],
#  'Occupation': ['Full TimeOn-site',
#   'Full TimePart TimeFreelance / ProjectHybrid',
#   'Full TimeHybrid',
#   'InternshipHybrid',
#   'Full TimeRemote',
#   'Full TimeOn-site',
#   'Full TimeOn-site',
#   'Full TimeHybrid',
#   'Full TimeOn-site',
#   'Full TimeHybrid',
#   'Full TimeHybrid',
#   'Full TimeOn-site',
#   'Full TimeOn-site',
#   'Full TimeHybrid',
#   'Full Time'],
#  'Company': ['Egabi FSI',
#   'ProVision Group',
#   'Lumin',
#   'eT3 Tomorrow Information Technology',
#   'Madar Soft',
#   'Stellar Charter Nexus',
#   'Gazelle 3D Tech',
#   'Lumin',
#   'Xceed Contact Center',
#   'Link Development',
#   'Confidential',
#   'Lotus Tex ',
#   'Selah ElTelmeez For Publishing & printing',
#   'Link Development',
#   'GenBio AI'],
#  'Specs': ['Full TimeOn-siteEntry Level · 1 - 4 Yrs of Exp · IT/Software Development · Engineering - Telecom/Technology · Computer Science · Data Mining · Data Science · data scientist · Hadoop · Machine Learning · Python · SQL',
#   'Full TimePart TimeFreelance / ProjectHybridExperienced · 2 - 7 Yrs of Exp · IT/Software Development · AI · Computer Vision · Data Science · Machine Learning',
#   'Full TimeHybridExperienced · 3+ Yrs of Exp · IT/Software Development · Analyst/Research · Engineering - Telecom/Technology · Computer Science · Analysis · Mathematics · Data Analysis · Hadoop · Data Science · Information Technology (IT)',
#   'InternshipHybridEntry Level · IT/Software Development · Computer Science · Software Development · Software Engineering · Computer Engineering · Back-End Development · Front-End Development · front-end web development · Software Testing · Data Engineering',
#   'Full TimeRemoteExperienced · 3 - 5 Yrs of Exp · IT/Software Development · Engineering - Telecom/Technology · computer · AI · NLP · Engineering · Information Technology (IT) · CUDA · Linux · Computer Science',
#   'Full TimeOn-siteExperienced · 2+ Yrs of Exp · IT/Software Development · Analyst/Research · Engineering - Telecom/Technology · AI · APIs · Computer Science · Development · Engineering · Frameworks · Information Technology (IT)',
#   'Full TimeOn-siteExperienced · 2+ Yrs of Exp · males_only · Installation/Maintenance/Repair · 3D Printing · Machines · Maintenance',
#   'Full TimeHybridExperienced · 3 - 5 Yrs of Exp · IT/Software Development · AI · Artificial Intelligence · Computer Vision · Machine Learning · TensorFlow · Python · Computer Science · Programming · PyTorch',
#   'Full TimeOn-siteExperienced · 3+ Yrs of Exp · Analyst/Research · Engineering - Telecom/Technology · ETL · Data Analysis · Communication skills · Python · SQL · Business Intelligence · PowerBI · Pandas',
#   'Full TimeHybridExperienced · 2 - 5 Yrs of Exp · IT/Software Development · Engineering - Telecom/Technology · Computer Science · BI · Software Engineering · SQL · Software Development · Power BI · SSRS · SQL Server',
#   'Full TimeHybridManager · 10+ Yrs of Exp · Business Development · IT/Software Development · Engineering - Telecom/Technology · Azure · Computer Science · developer · Engineering · ERP System · Information Technology (IT) · ERP',
#   'Full TimeOn-siteExperienced · 1 - 3 Yrs of Exp · males_only · Manufacturing/Production · Engineering - Other · Engineering · Textile · Production',
#   'Full TimeOn-siteExperienced · 4 - 6 Yrs of Exp · Accounting/Finance · Accounting · analytical · Communication · Cost Accounting · ERP System · Finance · Financial Management · Cost · ERP',
#   'Full TimeHybridManager · 5+ Yrs of Exp · IT/Software Development · Operations/Management · Engineering - Telecom/Technology · Computer Science · BI · Software Engineering · SQL · Software Development · Power BI · SSRS',
#   'Full TimeNot specified · IT/Software Development · Analyst/Research · Engineering - Telecom/Technology · computer science · information technology (it) · engineering · python · research · software engineering · machine learning']}

# %%
import pandas as pd
df = pd.DataFrame(scraped_data)
df
# Out:
#                                                 Title  \
# 0                                      Data Scientist
# 1                                         AI Engineer
# 2                                      Data Scientist
# 3   Graduate Internship: Enterprise Software Engin...
# 4   AI Engineer (Computer Vision, Speech, NLP & Ge...
# 5   AI Engineer (Custom AI Solutions & GPT Tools) ...
# 6                   3D Printer Maintenance Technician
# 7                                  Senior AI Engineer
# 8                                 Senior Data Analyst
# 9                                  Senior AI Engineer
# 10                       Software Development Manager
# 11                                   Textile Engineer
# 12    Senior Cost Accountant (Manufacturing Industry)
# 13                             AI Engineering Manager
# 14              Research Scientist (AI) - Interactome
#
#                                                  Link  \
# 0   https://wuzzuf.nethttps://wuzzuf.net/jobs/p/8o...
# 1   https://wuzzuf.nethttps://wuzzuf.net/jobs/p/qg...
# 2   https://wuzzuf.nethttps://wuzzuf.net/jobs/p/bu...
# 3   https://wuzzuf.nethttps://wuzzuf.net/internshi...
# 4   https://wuzzuf.nethttps://wuzzuf.net/jobs/p/go...
# 5   https://wuzzuf.nethttps://wuzzuf.net/jobs/p/cf...
# 6   https://wuzzuf.nethttps://wuzzuf.net/jobs/p/mg...
# 7   https://wuzzuf.nethttps://wuzzuf.net/jobs/p/jQ...
# 8   https://wuzzuf.nethttps://wuzzuf.net/jobs/p/kb...
# 9   https://wuzzuf.nethttps://wuzzuf.net/jobs/p/id...
# 10  https://wuzzuf.nethttps://wuzzuf.net/jobs/p/6u...
# 11  https://wuzzuf.nethttps://wuzzuf.net/jobs/p/8c...
# 12  https://wuzzuf.nethttps://wuzzuf.net/jobs/p/bt...
# 13  https://wuzzuf.nethttps://wuzzuf.net/jobs/p/x9...
# 14  https://wuzzuf.nethttps://wuzzuf.net/jobs/p/g/...
#
#                                      Occupation  \
# 0                              Full TimeOn-site
# 1   Full TimePart TimeFreelance / ProjectHybrid
# 2                               Full TimeHybrid
# 3                              InternshipHybrid
# 4                               Full TimeRemote
# 5                              Full TimeOn-site
# 6                              Full TimeOn-site
# 7                               Full TimeHybrid
# 8                              Full TimeOn-site
# 9                               Full TimeHybrid
# 10                              Full TimeHybrid
# 11                             Full TimeOn-site
# 12                             Full TimeOn-site
# 13                              Full TimeHybrid
# 14                                    Full Time
#
#                                       Company  \
# 0                                   Egabi FSI
# 1                             ProVision Group
# 2                                       Lumin
# 3         eT3 Tomorrow Information Technology
# 4                                  Madar Soft
# 5                       Stellar Charter Nexus
# 6                             Gazelle 3D Tech
# 7                                       Lumin
# 8                        Xceed Contact Center
# 9                            Link Development
# 10                               Confidential
# 11                                 Lotus Tex
# 12  Selah ElTelmeez For Publishing & printing
# 13                           Link Development
# 14                                  GenBio AI
#
#                                                 Specs
# 0   Full TimeOn-siteEntry Level · 1 - 4 Yrs of Exp...
# 1   Full TimePart TimeFreelance / ProjectHybridExp...
# 2   Full TimeHybridExperienced · 3+ Yrs of Exp · I...
# 3   InternshipHybridEntry Level · IT/Software Deve...
# 4   Full TimeRemoteExperienced · 3 - 5 Yrs of Exp ...
# 5   Full TimeOn-siteExperienced · 2+ Yrs of Exp · ...
# 6   Full TimeOn-siteExperienced · 2+ Yrs of Exp · ...
# 7   Full TimeHybridExperienced · 3 - 5 Yrs of Exp ...
# 8   Full TimeOn-siteExperienced · 3+ Yrs of Exp · ...
# 9   Full TimeHybridExperienced · 2 - 5 Yrs of Exp ...
# 10  Full TimeHybridManager · 10+ Yrs of Exp · Busi...
# 11  Full TimeOn-siteExperienced · 1 - 3 Yrs of Exp...
# 12  Full TimeOn-siteExperienced · 4 - 6 Yrs of Exp...
# 13  Full TimeHybridManager · 5+ Yrs of Exp · IT/So...
# 14  Full TimeNot specified · IT/Software Developme...

# %%
df.to_csv('mljobs.csv', index=False)

# %%
from scrap_jobs import scrap

# %%
from titles import get_titles
get_titles()
# Out:
# Jobs Scraped Successfully
# ['Data Scientist',
#  'AI Engineer',
#  'Data Scientist',
#  'Graduate Internship: Enterprise Software Engineering',
#  'AI Engineer (Computer Vision, Speech, NLP & Generative AI)',
#  'AI Engineer (Custom AI Solutions & GPT Tools) – On-Site',
#  '3D Printer Maintenance Technician',
#  'Senior AI Engineer',
#  'Senior Data Analyst',
#  'Senior AI Engineer',
#  'Software Development Manager',
#  'Textile Engineer',
#  'Senior Cost Accountant (Manufacturing Industry)',
#  'AI Engineering Manager',
#  'Research Scientist (AI) - Interactome']

# %%
query = 'data scientist'
query = query.replace(' ', '+')
url ='https://wuzzuf.net/search/jobs/?q=' + query + '&a=hpb'
url
# Out:
# 'https://wuzzuf.net/search/jobs/?q=data+scientist&a=hpb'

# %%
response = requests.get(url)
soup = BeautifulSoup(response.content, 'lxml')

# %%
soup.find('div', {'class': 'css-8neukt'})

# %%
soup.find("div", {'class': 'css-7o92qm'}).text
# Out:
# 'Showing 1 - 15 of 2212'

# %%
s = soup.find("li", {'class': 'css-8neukt'}).text
s
# Out:
# 'Showing 1 - 15 of 22'

# %%
s.split('of ')
# Out:
# ['Showing 1 - 15 ', '22']

# %%
s.split('of ')[1]
# Out:
# '22'

# %%
jobs = int(s.split('of ')[1])
jobs
# Out:
# 22

# %%
jobs / 15
# Out:
# 1.4666666666666666

# %%
import math
math.ceil( jobs / 15)
# Out:
# 2

# %%
def find_no_of_pages(query):
    query = query.replace(' ', '+')
    url = 'https://wuzzuf.net/search/jobs/?q=' + query + '&a=hpb'
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'lxml')
    txt = soup.find("li", {'class': 'css-8neukt'}).text
    jobs = int(s.split('of ')[1])
    pages = math.ceil(jobs / 15)
    return pages

# %%
query = 'python developer'
query = query.replace(' ', '%20')
pages = 3
for pageNo in range(pages):
    print('https://wuzzuf.net/search/jobs/?q=' + query + '&start=' + str(pageNo))
# Out:
# https://wuzzuf.net/search/jobs/?q=python%20developer&start=0
# https://wuzzuf.net/search/jobs/?q=python%20developer&start=1
# https://wuzzuf.net/search/jobs/?q=python%20developer&start=2
