# %% [markdown]
# <a href="https://colab.research.google.com/github/abdel2ty/IntenseAI_Notebooks_v1/blob/main/linear_algebra_with_numpy_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://www.zero-grad.com/">
#          <img alt="Zero Grad" src="https://i.postimg.cc/y8LZ0CM6/linear-Algebra.png" >
#       </a>

# %%
import numpy as np

# %% [markdown]
# #Transpose

# %% [markdown]
# ![transpose.png](data:image/png;base64,...)

# %% [markdown]
# ![](https://chortle.ccsu.edu/vectorlessons/vmch13/mtrxTrans2.gif)

# %%
v = np.array([1,2,3])
print (v)
# Out:
# [1 2 3]

# %%
v2 = v.T
print (v2)
# Out:
# [1 2 3]

# %%
print(v.shape)
print(v2.shape)
# Out:
# (3,)
# (3,)

# %%
m = np.array([[1,2,3]])
print (m)
# Out:
# [[1 2 3]]

# %%
m2 = m.T
print (m2)
# Out:
# [[1]
#  [2]
#  [3]]

# %%
print(m.shape)
print(m2.shape)
# Out:
# (1, 3)
# (3, 1)

# %%
m = np.array ([[11, 12, 13], [21, 22, 23], [31, 32, 33], [5, 6, 7]])
print (m)
# Out:
# [[11 12 13]
#  [21 22 23]
#  [31 32 33]
#  [ 5  6  7]]

# %%
m2 = m.T
print (m2)
# Out:
# [[11 21 31  5]
#  [12 22 32  6]
#  [13 23 33  7]]

# %%
print(m.shape)
print(m2.shape)
# Out:
# (4, 3)
# (3, 4)

# %%
np.transpose(m)  # m.T
# Out:
# array([[11, 21, 31,  5],
#        [12, 22, 32,  6],
#        [13, 23, 33,  7]])

# %% [markdown]
# # Determinant

# %% [markdown]
# ![](https://www.sharetechnote.com/image/EngMath_Matrix_Det_2x2_02.png)
#
# ![](https://www.sharetechnote.com/image/EngMath_Matrix_Det_Fig_01.PNG)
#
# ![](https://www.sharetechnote.com/image/EngMath_Matrix_Det_Fig_02.PNG)
#
# Image Credit : [sharetechnote](https://www.sharetechnote.com/html/Handbook_EngMath_Matrix_Determinent.html)

# %% [markdown]
# > * Only for Square Matrix
# * Only for Invertible Matrix

# %%
A = np.array ([[4,3],[3,2]])
A
# Out:
# array([[4, 3],
#        [3, 2]])

# %%
np.linalg.det(A)        # (4*2 - 3*3)
# Out:
# -1.0

# %% [markdown]
# **Useful Source : [Mathisfun: Determinant](https://www.mathsisfun.com/algebra/matrix-determinant.html)**

# %% [markdown]
# # Inverse

# %% [markdown]
# ![](https://www.thecalculator.co/includes/forms/assets/img/Inverse%20Matrix%202x2%20Formula.jpg)
#
# Image Credit : [The Calculator](https://www.thecalculator.co/math/Inverse-Matrix-Calculator-724.html)

# %%
A = np.array ([[4,3],[3,2]])
A
# Out:
# array([[4, 3],
#        [3, 2]])

# %%
B = np.linalg.inv(A)
B
# Out:
# array([[-2.,  3.],
#        [ 3., -4.]])

# %% [markdown]
# # Dot Product

# %% [markdown]
# ![](https://www.mathsisfun.com/algebra/images/matrix-multiply-a.svg)
#
# ![](https://www.mathsisfun.com/algebra/images/matrix-multiply-b.svg)
#
# ![](https://www.mathsisfun.com/algebra/images/matrix-multiply-c.svg)

# %%
np.dot(A,B)  # A.dot(B)
# Out:
# array([[1., 0.],
#        [0., 1.]])

# %%
np.dot(B,A)
# Out:
# array([[1., 0.],
#        [0., 1.]])

# %% [markdown]
# **Useful Source : [Mathisfun: Dot Product](https://www.mathsisfun.com/algebra/matrix-multiplying.html)**

# %%
A = np.array([[1,2,3], [4, 5, 6]])
B = np.array([[7,8], [9,10], [11,12]])

# %%
np.dot(A,B)
# Out:
# array([[ 58,  64],
#        [139, 154]])

# %%
np.dot(B,A)
# Out:
# array([[ 39,  54,  69],
#        [ 49,  68,  87],
#        [ 59,  82, 105]])
